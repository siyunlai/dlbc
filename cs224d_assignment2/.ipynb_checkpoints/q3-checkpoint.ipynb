# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

from q3_RNNLM import *

# %%
test_RNNLM()
# Out:
# 929589.0 total words with 10000 uniques
# INPUTS [<tf.Tensor 'RNNLM/Embedding/Squeeze:0' shape=<unknown> dtype=float32>, <tf.Tensor 'RNNLM/Embedding/Squeeze_1:0' shape=<unknown> dtype=float32>, <tf.Tensor 'RNNLM/Embedding/Squeeze_2:0' shape=<unknown> dtype=float32>, <tf.Tensor 'RNNLM/Embedding/Squeeze_3:0' shape=<unknown> dtype=float32>, <tf.Tensor 'RNNLM/Embedding/Squeeze_4:0' shape=<unknown> dtype=float32>, <tf.Tensor 'RNNLM/Embedding/Squeeze_5:0' shape=<unknown> dtype=float32>, <tf.Tensor 'RNNLM/Embedding/Squeeze_6:0' shape=<unknown> dtype=float32>, <tf.Tensor 'RNNLM/Embedding/Squeeze_7:0' shape=<unknown> dtype=float32>, <tf.Tensor 'RNNLM/Embedding/Squeeze_8:0' shape=<unknown> dtype=float32>, <tf.Tensor 'RNNLM/Embedding/Squeeze_9:0' shape=<unknown> dtype=float32>]
# OUTPUT TENSOR:  Tensor("RNNLM/stack:0", shape=(64, 10, 10000), dtype=float32)
# [<tf.Tensor 'RNNLM/gradients/RNNLM/Embedding/split_grad/concat:0' shape=(?, 10, 50) dtype=float32>, None, None]
# ...
